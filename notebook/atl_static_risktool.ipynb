# %% [markdown]
# ## Atlantic Trading Static RiskTool

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Code toggle"></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Code toggle"></form>

# %%
# %cd C:\\RiskMatrices\src
from risk.engine import RiskEngine
# Out:
# C:\RiskMatrices\src

# %%
risk_engine = RiskEngine(product="euribor", scenario="ECB")
#compute risk matrices
total_portfolio_matrix = risk_engine.run_pricing_and_risk()
#extract the heatplot figures from model
w_portfolio_matrix = risk_engine._models["w"]["graph"]
m_portfolio_matrix = risk_engine._models["m"]["graph"]
g_portfolio_matrix = risk_engine._models["g"]["graph"]
b_portfolio_matrix = risk_engine._models["b"]["graph"]
portfolio_matrix = risk_engine._models["all"]["graph"]
# Out:
# C:\RiskMatrices\src\model\datamodel.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.model[param] = pd.to_datetime(self.model[param])
# C:\RiskMatrices\src\model\datamodel.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.model[param] = self.model.apply(lambda x: function(x), axis=1)
# C:\RiskMatrices\src\model\datamodel.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# ### Summary

# %%
portfolio_matrix.set_size_inches(20, 14)
display(portfolio_matrix)

# %% [markdown]
# ### Whites

# %%
w_portfolio_matrix.set_size_inches(20, 14)
display(w_portfolio_matrix)

# %% [markdown]
# ### Mids

# %%
m_portfolio_matrix.set_size_inches(20, 14)
display(m_portfolio_matrix)

# %% [markdown]
# ### Greens

# %%
g_portfolio_matrix.set_size_inches(20, 14)
display(g_portfolio_matrix)

# %% [markdown]
# ### Blues

# %%
b_portfolio_matrix.set_size_inches(20, 14)
display(b_portfolio_matrix)

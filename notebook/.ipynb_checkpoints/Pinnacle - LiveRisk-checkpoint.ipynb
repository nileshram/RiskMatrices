# %% [markdown]
# ## Pinnacle Live Risks

# %%
# %cd /home/nilesh/workspace/PortfolioRisk/
import sys
sys.path.append('/home/nilesh/workspace/PortfolioRisk/src/')
# Out:
# /home/nilesh/workspace/PortfolioRisk

# %%
import warnings
warnings.filterwarnings('ignore')
from model.data import PortfolioManager

pinnacle = PortfolioManager(portfolio_name="tuco", params_portfolio="arc")

# %% [markdown]
# ### Sterling

# %%
pinnacle.live_risk_sterling
# Out:
#                            nDelta        nGamma       nTheta         nVega
# underlying_future_id
# L H21                -6221.212720    378.475559    -2.308981    894.171708
# L H22                  374.000000      0.000000     0.000000      0.000000
# L M20                -1545.946724  34500.348629 -1819.930937  32524.639030
# L M21                 1073.061821  -4357.125294   382.838464  19139.933703
# L M22                 -554.926487 -14883.875117   502.269484 -10283.905178
# L M23                 -228.966571  -4209.637302   112.620437  -2560.166850
# L U20                 -714.085652   9711.981882  -188.993505  10552.104664
# L U21                -2108.361898  -2787.752605    52.315231  -4212.879004
# L U22                 -188.416497   2965.826075   -88.191125   5363.116499
# L Z20                 8539.952604   4473.410416   -93.124621  10685.145727
# L Z21                  995.159529   -658.132034     9.272602  -1469.006606
# L Z22                    3.782793   -611.128071    19.124311  -1817.086814
# Total                 -575.959801  24522.392138 -1114.108640  58816.066879

# %% [markdown]
# ### Euribor

# %%
pinnacle.live_risk_euribor
# Out:
#                            nDelta        nGamma      nTheta         nVega
# underlying_future_id
# I H21                  144.372632  -3780.499907   36.068359  -9054.294026
# I H22                -1820.000000      0.000000    0.000000      0.000000
# I H23                  707.000000      0.000000    0.000000      0.000000
# I M20                 -285.313667   -991.235643  -18.409145   -343.721054
# I M21                 2853.872097  -3653.023155   34.024931 -13536.200519
# I M22                 1533.347967  -2012.673262   82.171690  -1352.780862
# I M23                   80.011388 -10310.732138  456.288807  -8044.895398
# I U20                 -140.645046  27589.222145 -356.108493  31828.048530
# I U21                 3993.605412  -1187.689308   17.070034   8080.365759
# I U22                  223.767640   -406.392936    9.166196   -645.527863
# I U23                  106.872000   2053.895088  -73.883302   4095.722141
# I Z20                -3584.643505   5627.488854  -47.983668   8689.896798
# I Z21                -3014.490049 -15558.293795  183.265915 -34585.685118
# I Z22                 -622.122242   1097.223041  -24.651336   2855.403628
# I Z23                 -188.497607   2675.007907  -63.980364   7132.580349
# Total                  -12.862982   1142.296890  233.039625  -4881.087634

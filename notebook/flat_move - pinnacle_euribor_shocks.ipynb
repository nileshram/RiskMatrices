# %% [markdown]
# ## Atlantic Trading - Pinnacle - Euribor Shocks

# %%
# %cd /home/nilesh/workspace/RiskMatrices/
import sys
import warnings
warnings.filterwarnings('ignore')
sys.path.append('/home/nilesh/workspace/RiskMatrices/src/')
from risk.engine import RiskEngine
# Out:
# /home/nilesh/workspace/RiskMatrices

# %%
risk_engine = RiskEngine(product="euribor", scenario="flat_move")
#compute risk matrices
total_portfolio_matrix = risk_engine.run_pricing_and_risk()
#extract the heatplot figures from model
w_portfolio_matrix = risk_engine._models["w"]["graph"]
m_portfolio_matrix = risk_engine._models["m"]["graph"]
g_portfolio_matrix = risk_engine._models["g"]["graph"]
b_portfolio_matrix = risk_engine._models["b"]["graph"]
portfolio_matrix = risk_engine._models["all"]["graph"]

# %% [markdown]
# ### Summary

# %%
portfolio_matrix.set_size_inches(20, 14)
display(portfolio_matrix)

# %% [markdown]
# ### Whites

# %%
w_portfolio_matrix.set_size_inches(20, 14)
display(w_portfolio_matrix)

# %% [markdown]
# ### Mids

# %%
m_portfolio_matrix.set_size_inches(20, 14)
display(m_portfolio_matrix)

# %% [markdown]
# ### Greens

# %%
g_portfolio_matrix.set_size_inches(20, 14)
display(g_portfolio_matrix)

# %% [markdown]
# ### Blues

# %%
b_portfolio_matrix.set_size_inches(20, 14)
display(b_portfolio_matrix)

# %% [markdown]
# SHOCKS:
# "fut": {
# 							"up": {
# 								"ex1": 0.00,
# 								"ex2": 0.005,
# 								"ex3": 0.075,
# 								"ex4": 0.01,
# 								"ex5": 0.0125,
# 								"ex6": 0.015,
# 								"ex7": 0.0175,
# 								"ex8": 0.02,
# 								"ex9": 0.0225,
# 								"ex10": 0.025,
# 								"ex11": 0.0275,
# 								"ex12": 0.03,
# 								"ex13": 0.0325,
# 								"ex14": 0.035,
# 								"ex15": 0.0375,
# 								"ex16": 0.04
# 							},
# 							"down": {
# 								"ex1": 0.00,
# 								"ex2": -0.005,
# 								"ex3": -0.075,
# 								"ex4": -0.01,
# 								"ex5": -0.0125,
# 								"ex6": -0.015,
# 								"ex7": -0.0175,
# 								"ex8": -0.02,
# 								"ex9": -0.0225,
# 								"ex10": -0.025,
# 								"ex11": -0.0275,
# 								"ex12": -0.03,
# 								"ex13": -0.0325,
# 								"ex14": -0.035,
# 								"ex15": -0.0375,
# 								"ex16": -0.04
# 							}
# 						},
# 		"vol": {
# 							"up": {
# 								"ex1": 0.05,
# 								"ex2": 0.10,
# 								"ex3": 0.15,
# 								"ex4": 0.20,
# 								"ex5": 0.25,
# 								"ex6": 0.30,
# 								"ex7": 0.35,
# 								"ex8": 0.40,
# 								"ex9": 0.45,
# 								"ex10": 0.50,
# 								"ex11": 0.50,
# 								"ex12": 0.50,
# 								"ex13": 0.50,
# 								"ex14": 0.50,
# 								"ex15": 0.50,
# 								"ex16": 0.50
# 							},
# 							"down": {
# 								"ex1": -0.05,
# 								"ex2": -0.10,
# 								"ex3": -0.15,
# 								"ex4": -0.20,
# 								"ex5": -0.25,
# 								"ex6": -0.30,
# 								"ex7": -0.35,
# 								"ex8": -0.40,
# 								"ex9": -0.45,
# 								"ex10": -0.50,
# 								"ex11": -0.50,
# 								"ex12": -0.50,
# 								"ex13": -0.50,
# 								"ex14": -0.50,
# 								"ex15": -0.50,
# 								"ex16": -0.50
# 							}
